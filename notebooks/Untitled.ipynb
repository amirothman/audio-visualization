# %%
from skimage.io import imread, imsave, imshow

# %%
input_image = imread("../data/input/api.jpg")

# %%
from skimage.transform import resize

input_imge = resize(input_image, (480, 640))

# %%
input_image = input_imge

# %%
imshow(input_image)

# %%
import numpy as np

# %%
np.max(input_image)
# Out:
# 0.9921568627450981

# %%
np.min(input_image)
# Out:
# 0.0

# %%
# Out:
# array([[[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        ...,
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
# ...
